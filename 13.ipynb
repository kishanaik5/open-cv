# %% [markdown]
# 13 . Apply a Gaussian filter to an image to reduce noise. Display the original and filtered images side by side for comparison.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Load the image
image = cv2.imread('/content/deadpool-wolverine-wallpaper-preview.jpg')  # Replace with your image file

# Apply Gaussian filter
filtered_image = cv2.GaussianBlur(image, (5, 5),0)  # Kernel size (5, 5)

# Concatenate the original and filtered images for side-by-side display
comparison = np.hstack((image, filtered_image))

# Display the comparison
plt.imshow(comparison)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
