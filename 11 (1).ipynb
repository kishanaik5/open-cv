# %% [markdown]
# 11 . Implement a region counting algorithm to count the number of distinct regions in a segmented image. Display the original image with the regions labeled by their count.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load the image in grayscale
image = cv2.imread('/content/deadpool-wolverine-wallpaper-preview.jpg', cv2.IMREAD_GRAYSCALE)

# Threshold the image to binary
_,binary = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Find connected components
n, l, _, c = cv2.connectedComponentsWithStats(binary)

output = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for i in range(1, n):
    x, y = map(int, c[i])
    cv2.putText(image, str(i), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.2, (0, 255, 0))

# Show results
print(f"Distinct regions: {n - 1}")
cv2_imshow(output)
# Out:
# Distinct regions: 469
# <PIL.Image.Image image mode=RGB size=1334x728>
